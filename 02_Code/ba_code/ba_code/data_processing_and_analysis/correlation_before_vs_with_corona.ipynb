# %%
import warnings
warnings.filterwarnings('ignore')
from ba_code.data_processing_and_analysis.data_analyzer import DataAnalyzer
from ba_code.data_processing_and_analysis.google_and_tripadvisor.restaurant_review_data_uri import \
    TripadvisorRestaurantReviewDataUri, GoogleRestaurantReviewDataUri, RestaurantReviewDataType
from ba_code.data_processing_and_analysis.prognolite.prognolite_restaurant_constants import \
    Restaurant

dataAnalyzer = DataAnalyzer()

# %%
data_type = RestaurantReviewDataType.GOOGLE_REVIEW
time_period = "m"
rating_date_offset_in_months = 0

# TODO: 1. get plots of all rest overall rating vs turnover
"""
dataAnalyzer.plot_overall_rating_development_and_average_turnover_per_time_period_for_all_restaurants(
    restaurant_review_data_type=RestaurantReviewDataType.GOOGLE_REVIEW,
    time_period="m",
    rating_date_offset_in_months=0,
    filter_corona_data=False)
"""

# TODO: look at correlations overall rating vs turnover
df_pearson_spearman_before_corona = dataAnalyzer.compute_correlation_between_average_turnover_and_overall_rating_development_for_all_restaurants(
    restaurant_review_data_type=data_type,
    time_period=time_period,
    rating_date_offset_in_months=rating_date_offset_in_months,
    filter_corona_data=True
)

df_pearson_spearman_with_corona = dataAnalyzer.compute_correlation_between_average_turnover_and_overall_rating_development_for_all_restaurants(
    restaurant_review_data_type=data_type,
    time_period=time_period,
    rating_date_offset_in_months=rating_date_offset_in_months,
    filter_corona_data=False
)
# Out:
# Restaurant: fwg-butcher-uster
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                           1.00000
# overall_rating_development                                -0.93856
#
#                                   overall_rating_development
# average_turnover_per_time_period                    -0.93856
# overall_rating_development                           1.00000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                               1.0
# overall_rating_development                                    -1.0
#
#                                   overall_rating_development
# average_turnover_per_time_period                        -1.0
# overall_rating_development                               1.0
# Restaurant: fwg-negishi-metalli
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.285727
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.285727
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.273359
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.273359
# overall_rating_development                          1.000000
# Restaurant: fwg-butcher-aarbergergasse
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                           1.00000
# overall_rating_development                                 0.77213
#
#                                   overall_rating_development
# average_turnover_per_time_period                     0.77213
# overall_rating_development                           1.00000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.613642
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.613642
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-aarbergergasse
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.745072
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.745072
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.646332
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.646332
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-barfi
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.006887
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.006887
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.280584
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.280584
# overall_rating_development                          1.000000
# Restaurant: fwg-missmiu-europaallee
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.821629
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.821629
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.714286
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.714286
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-mallofSwitzerland
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.718542
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.718542
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.668376
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.668376
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-mattenhof
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.266858
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.266858
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.059881
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.059881
# overall_rating_development                          1.000000
# Restaurant: fwg-butcher-metalli
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.817648
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.817648
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.719176
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.719176
# overall_rating_development                          1.000000
# Restaurant: fwg-negishi-pilatusstrasse
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.838725
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.838725
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.895128
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.895128
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-richti
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.570566
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.570566
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.578222
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.578222
# overall_rating_development                          1.000000
# Restaurant: fwg-outback-stad
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.203484
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.203484
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.339172
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.339172
# overall_rating_development                          1.000000
# Restaurant: fwg-negishi-steinen
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.138761
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.138761
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.248906
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.248906
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-uster
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.477006
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.477006
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                               1.0
# overall_rating_development                                     0.8
#
#                                   overall_rating_development
# average_turnover_per_time_period                         0.8
# overall_rating_development                               1.0
# Restaurant: fwg-butcher-zuerichWest
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.450908
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.450908
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.108366
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.108366
# overall_rating_development                          1.000000
# Restaurant: fwg-butcher-uster
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.480032
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.480032
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.306079
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.306079
# overall_rating_development                          1.000000
# Restaurant: fwg-negishi-metalli
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.156824
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.156824
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.352583
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.352583
# overall_rating_development                          1.000000
# Restaurant: fwg-butcher-aarbergergasse
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.642345
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.642345
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.164171
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.164171
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-aarbergergasse
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.325461
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.325461
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.570931
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.570931
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-barfi
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.036967
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.036967
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.020288
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.020288
# overall_rating_development                          1.000000
# Restaurant: fwg-missmiu-europaallee
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                           1.00000
# overall_rating_development                                 0.20873
#
#                                   overall_rating_development
# average_turnover_per_time_period                     0.20873
# overall_rating_development                           1.00000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.025401
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.025401
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-mallofSwitzerland
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.429584
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.429584
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.417738
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.417738
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-mattenhof
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.075013
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.075013
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                           1.00000
# overall_rating_development                                 0.01779
#
#                                   overall_rating_development
# average_turnover_per_time_period                     0.01779
# overall_rating_development                           1.00000
# Restaurant: fwg-butcher-metalli
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.744271
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.744271
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.619702
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.619702
# overall_rating_development                          1.000000
# Restaurant: fwg-negishi-pilatusstrasse
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.391396
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.391396
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.344716
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.344716
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-richti
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                           1.00000
# overall_rating_development                                -0.57585
#
#                                   overall_rating_development
# average_turnover_per_time_period                    -0.57585
# overall_rating_development                           1.00000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.668557
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.668557
# overall_rating_development                          1.000000
# Restaurant: fwg-outback-stad
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                           1.00000
# overall_rating_development                                -0.42815
#
#                                   overall_rating_development
# average_turnover_per_time_period                    -0.42815
# overall_rating_development                           1.00000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.701409
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.701409
# overall_rating_development                          1.000000
# Restaurant: fwg-negishi-steinen
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.000075
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.000075
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.042482
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.042482
# overall_rating_development                          1.000000
# Restaurant: fwg-nooch-uster
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.420981
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.420981
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.505195
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.505195
# overall_rating_development                          1.000000
# Restaurant: fwg-butcher-zuerichWest
#
# Pearson correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                                0.363058
#
#                                   overall_rating_development
# average_turnover_per_time_period                    0.363058
# overall_rating_development                          1.000000
#
# Spearman correlation:
#                                   average_turnover_per_time_period  \
# average_turnover_per_time_period                          1.000000
# overall_rating_development                               -0.161945
#
#                                   overall_rating_development
# average_turnover_per_time_period                   -0.161945
# overall_rating_development                          1.000000

# %%
from IPython.core.display import display, HTML
import pandas as pd

#data = df_pearson_spearman #pd.DataFrame({"A":[1,2,3,4,5], "B":[10,20,30,40,50]})
for restaurant in Restaurant:
    picture_name_before_corona = DataAnalyzer.get_picture_name(restaurant, filter_corona_data=True)
    df_pearson_spearman_before_corona.loc[df_pearson_spearman_before_corona["restaurant_name"] == picture_name_before_corona,'before_corona'] = \
        '<img src="{}" alt="img">'.format(picture_name_before_corona + ".png")
    picture_name_with_corona = DataAnalyzer.get_picture_name(restaurant, filter_corona_data=False)
    df_pearson_spearman_with_corona.loc[df_pearson_spearman_with_corona["restaurant_name"] == picture_name_with_corona,'with_corona'] = \
        '<img src="{}" alt="img">'.format(picture_name_with_corona + ".png")

df_pearson_spearman_before_corona["pearson_spearman"] = df_pearson_spearman_before_corona["pearson"].map('${:,.2f}'.format).astype(str) + ", " + df_pearson_spearman_before_corona["spearman"].map('${:,.2f}'.format).astype(str)
df_pearson_spearman_with_corona["pearson_spearman"] = df_pearson_spearman_with_corona["pearson"].map('${:,.2f}'.format).astype(str) + ", " + df_pearson_spearman_with_corona["spearman"].map('${:,.2f}'.format).astype(str)
df = pd.DataFrame({#"restaurant_name":[restaurant.value for restaurant in Restaurant],
              "pear_s_before":df_pearson_spearman_before_corona["pearson_spearman"].to_list(),
              "before_corona_img":df_pearson_spearman_before_corona["before_corona"].to_list(),
              "pear_s_with":df_pearson_spearman_with_corona["pearson_spearman"].to_list(),
              "with_corona_img":df_pearson_spearman_with_corona["with_corona"].to_list()})

display(HTML(df.to_html(escape=False, index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>pear_s_before</th>
#       <th>before_corona_img</th>
#       <th>pear_s_with</th>
#       <th>with_corona_img</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>$-0.94, $-1.00</td>
#       <td><img src="fwg-butcher-uster-before-corona.png" alt="img"></td>
#       <td>$-0.48, $-0.31</td>
#       <td><img src="fwg-butcher-uster-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.29, $-0.27</td>
#       <td><img src="fwg-negishi-metalli-before-corona.png" alt="img"></td>
#       <td>$-0.16, $-0.35</td>
#       <td><img src="fwg-negishi-metalli-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.77, $0.61</td>
#       <td><img src="fwg-butcher-aarbergergasse-before-corona.png" alt="img"></td>
#       <td>$0.64, $0.16</td>
#       <td><img src="fwg-butcher-aarbergergasse-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.75, $0.65</td>
#       <td><img src="fwg-nooch-aarbergergasse-before-corona.png" alt="img"></td>
#       <td>$0.33, $0.57</td>
#       <td><img src="fwg-nooch-aarbergergasse-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.01, $-0.28</td>
#       <td><img src="fwg-nooch-barfi-before-corona.png" alt="img"></td>
#       <td>$0.04, $0.02</td>
#       <td><img src="fwg-nooch-barfi-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.82, $0.71</td>
#       <td><img src="fwg-missmiu-europaallee-before-corona.png" alt="img"></td>
#       <td>$0.21, $-0.03</td>
#       <td><img src="fwg-missmiu-europaallee-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.72, $-0.67</td>
#       <td><img src="fwg-nooch-mallofSwitzerland-before-corona.png" alt="img"></td>
#       <td>$-0.43, $-0.42</td>
#       <td><img src="fwg-nooch-mallofSwitzerland-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.27, $0.06</td>
#       <td><img src="fwg-nooch-mattenhof-before-corona.png" alt="img"></td>
#       <td>$-0.08, $0.02</td>
#       <td><img src="fwg-nooch-mattenhof-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.82, $0.72</td>
#       <td><img src="fwg-butcher-metalli-before-corona.png" alt="img"></td>
#       <td>$0.74, $0.62</td>
#       <td><img src="fwg-butcher-metalli-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.84, $-0.90</td>
#       <td><img src="fwg-negishi-pilatusstrasse-before-corona.png" alt="img"></td>
#       <td>$-0.39, $-0.34</td>
#       <td><img src="fwg-negishi-pilatusstrasse-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.57, $-0.58</td>
#       <td><img src="fwg-nooch-richti-before-corona.png" alt="img"></td>
#       <td>$-0.58, $-0.67</td>
#       <td><img src="fwg-nooch-richti-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.20, $-0.34</td>
#       <td><img src="fwg-outback-stad-before-corona.png" alt="img"></td>
#       <td>$-0.43, $-0.70</td>
#       <td><img src="fwg-outback-stad-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.14, $-0.25</td>
#       <td><img src="fwg-negishi-steinen-before-corona.png" alt="img"></td>
#       <td>$-0.00, $-0.04</td>
#       <td><img src="fwg-negishi-steinen-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.48, $0.80</td>
#       <td><img src="fwg-nooch-uster-before-corona.png" alt="img"></td>
#       <td>$-0.42, $-0.51</td>
#       <td><img src="fwg-nooch-uster-after-corona.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.45, $-0.11</td>
#       <td><img src="fwg-butcher-zuerichWest-before-corona.png" alt="img"></td>
#       <td>$0.36, $-0.16</td>
#       <td><img src="fwg-butcher-zuerichWest-after-corona.png" alt="img"></td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np

np.round(1.5)
# Out:
# 2.0
