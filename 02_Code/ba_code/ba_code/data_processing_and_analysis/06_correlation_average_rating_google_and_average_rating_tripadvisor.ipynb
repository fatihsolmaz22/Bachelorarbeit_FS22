# %%
import warnings
warnings.filterwarnings('ignore')
from ba_code.data_processing_and_analysis.data_analyzer import DataAnalyzer, AnalyzerOption
from ba_code.data_processing_and_analysis.google_and_tripadvisor.restaurant_review_data_uri import \
    TripadvisorRestaurantReviewDataUri, GoogleRestaurantReviewDataUri, RestaurantReviewDataType
from ba_code.data_processing_and_analysis.prognolite.prognolite_restaurant_constants import \
    Restaurant

dataAnalyzer = DataAnalyzer()

# %% [markdown]
# ## Average rating google vs average rating tripadvisor

# %%
analyzer_option = AnalyzerOption.AVERAGE_RATING_GOOGLE_VS_AVERAGE_RATING_TRIPADVISOR
review_data_type = None
time_period = "m"
rating_date_offset_in_months = 0

# TODO: look at correlations overall rating vs turnover
df_pearson_spearman_before_corona = dataAnalyzer.compute_correlation_for_all_restaurants(
    analyzer_option=analyzer_option,
    restaurant_review_data_type=review_data_type,
    time_period=time_period,
    rating_date_offset_in_months=rating_date_offset_in_months,
    filter_corona_data=True)

df_pearson_spearman_with_corona = dataAnalyzer.compute_correlation_for_all_restaurants(
    analyzer_option=analyzer_option,
    restaurant_review_data_type=review_data_type,
    time_period=time_period,
    rating_date_offset_in_months=rating_date_offset_in_months,
    filter_corona_data=False)
# Out:
# Restaurant: fwg-butcher-uster
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.934533
# average_rating_per_time_period_y                          0.934533                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                               1.0                               0.5
# average_rating_per_time_period_y                               0.5                               1.0
# Restaurant: fwg-negishi-metalli
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.115926
# average_rating_per_time_period_y                          0.115926                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.071363
# average_rating_per_time_period_y                          0.071363                          1.000000
# Restaurant: fwg-butcher-aarbergergasse
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.159277
# average_rating_per_time_period_y                          0.159277                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.270369
# average_rating_per_time_period_y                          0.270369                          1.000000
# Restaurant: fwg-nooch-aarbergergasse
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.303532
# average_rating_per_time_period_y                          0.303532                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.253191
# average_rating_per_time_period_y                          0.253191                          1.000000
# Restaurant: fwg-nooch-barfi
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.004398
# average_rating_per_time_period_y                          0.004398                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.151588
# average_rating_per_time_period_y                          0.151588                          1.000000
# Restaurant: fwg-missmiu-europaallee
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.030733
# average_rating_per_time_period_y                          0.030733                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.178571
# average_rating_per_time_period_y                          0.178571                          1.000000
# Restaurant: fwg-nooch-mallofSwitzerland
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.083194
# average_rating_per_time_period_y                          0.083194                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                           1.00000                          -0.00611
# average_rating_per_time_period_y                          -0.00611                           1.00000
# Restaurant: fwg-nooch-mattenhof
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.599863
# average_rating_per_time_period_y                          0.599863                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.654654
# average_rating_per_time_period_y                          0.654654                          1.000000
# Restaurant: fwg-butcher-metalli
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.231115
# average_rating_per_time_period_y                          0.231115                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.089399
# average_rating_per_time_period_y                          0.089399                          1.000000
# Restaurant: fwg-negishi-pilatusstrasse
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.193909
# average_rating_per_time_period_y                          0.193909                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.046839
# average_rating_per_time_period_y                          0.046839                          1.000000
# Restaurant: fwg-nooch-richti
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.079362
# average_rating_per_time_period_y                         -0.079362                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.139283
# average_rating_per_time_period_y                         -0.139283                          1.000000
# Restaurant: fwg-outback-stad
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.267757
# average_rating_per_time_period_y                         -0.267757                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.273102
# average_rating_per_time_period_y                         -0.273102                          1.000000
# Restaurant: fwg-negishi-steinen
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.157701
# average_rating_per_time_period_y                         -0.157701                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.060669
# average_rating_per_time_period_y                         -0.060669                          1.000000
# Restaurant: fwg-nooch-uster
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                           1.00000                           0.79655
# average_rating_per_time_period_y                           0.79655                           1.00000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.866025
# average_rating_per_time_period_y                          0.866025                          1.000000
# Restaurant: fwg-butcher-zuerichWest
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.041055
# average_rating_per_time_period_y                         -0.041055                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.040858
# average_rating_per_time_period_y                         -0.040858                          1.000000
# Restaurant: fwg-butcher-uster
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.498472
# average_rating_per_time_period_y                          0.498472                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.357567
# average_rating_per_time_period_y                          0.357567                          1.000000
# Restaurant: fwg-negishi-metalli
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.053892
# average_rating_per_time_period_y                          0.053892                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.002993
# average_rating_per_time_period_y                          0.002993                          1.000000
# Restaurant: fwg-butcher-aarbergergasse
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.130643
# average_rating_per_time_period_y                          0.130643                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.163625
# average_rating_per_time_period_y                          0.163625                          1.000000
# Restaurant: fwg-nooch-aarbergergasse
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.262653
# average_rating_per_time_period_y                          0.262653                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.233593
# average_rating_per_time_period_y                          0.233593                          1.000000
# Restaurant: fwg-nooch-barfi
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.106803
# average_rating_per_time_period_y                         -0.106803                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.015679
# average_rating_per_time_period_y                          0.015679                          1.000000
# Restaurant: fwg-missmiu-europaallee
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.207525
# average_rating_per_time_period_y                          0.207525                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.233695
# average_rating_per_time_period_y                          0.233695                          1.000000
# Restaurant: fwg-nooch-mallofSwitzerland
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.056821
# average_rating_per_time_period_y                          0.056821                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.033337
# average_rating_per_time_period_y                          0.033337                          1.000000
# Restaurant: fwg-nooch-mattenhof
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.003278
# average_rating_per_time_period_y                          0.003278                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.058036
# average_rating_per_time_period_y                         -0.058036                          1.000000
# Restaurant: fwg-butcher-metalli
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.108472
# average_rating_per_time_period_y                          0.108472                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.033028
# average_rating_per_time_period_y                          0.033028                          1.000000
# Restaurant: fwg-negishi-pilatusstrasse
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.116388
# average_rating_per_time_period_y                         -0.116388                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.173403
# average_rating_per_time_period_y                         -0.173403                          1.000000
# Restaurant: fwg-nooch-richti
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.039519
# average_rating_per_time_period_y                          0.039519                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.054254
# average_rating_per_time_period_y                         -0.054254                          1.000000
# Restaurant: fwg-outback-stad
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.291465
# average_rating_per_time_period_y                         -0.291465                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.321287
# average_rating_per_time_period_y                         -0.321287                          1.000000
# Restaurant: fwg-negishi-steinen
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.069496
# average_rating_per_time_period_y                         -0.069496                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.043477
# average_rating_per_time_period_y                         -0.043477                          1.000000
# Restaurant: fwg-nooch-uster
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.341707
# average_rating_per_time_period_y                          0.341707                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                          0.013859
# average_rating_per_time_period_y                          0.013859                          1.000000
# Restaurant: fwg-butcher-zuerichWest
#
# Pearson correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.203733
# average_rating_per_time_period_y                         -0.203733                          1.000000
#
# Spearman correlation:
#                                   average_rating_per_time_period_x  average_rating_per_time_period_y
# average_rating_per_time_period_x                          1.000000                         -0.191638
# average_rating_per_time_period_y                         -0.191638                          1.000000

# %%
from IPython.core.display import display, HTML
import pandas as pd

#data = df_pearson_spearman #pd.DataFrame({"A":[1,2,3,4,5], "B":[10,20,30,40,50]})
for restaurant in Restaurant:
    picture_name_before_corona = DataAnalyzer.get_picture_name(restaurant, filter_corona_data=True)

    df_pearson_spearman_before_corona.loc[df_pearson_spearman_before_corona["restaurant_name"] == picture_name_before_corona,'before_corona'] = \
        '<img src="{}" alt="img">'.format(picture_name_before_corona + "-corr.png")
    """
    df_pearson_spearman_before_corona.loc[df_pearson_spearman_before_corona["restaurant_name"] == picture_name_before_corona,'before_corona'] = \
    '<table><tr><td> <img src="{}" alt="img"></td></tr><tr><td> <img src="{}" alt="img"></td></tr></table>' \
    .format(
        picture_name_before_corona + "-lineplot.png",
        picture_name_before_corona + "-corr.png")
    """
    picture_name_with_corona = DataAnalyzer.get_picture_name(restaurant, filter_corona_data=False)

    df_pearson_spearman_with_corona.loc[df_pearson_spearman_with_corona["restaurant_name"] == picture_name_with_corona,'with_corona'] = \
        '<img src="{}" alt="img">'.format(picture_name_with_corona + "-corr.png")
    """
    df_pearson_spearman_with_corona.loc[df_pearson_spearman_with_corona["restaurant_name"] == picture_name_with_corona,'with_corona'] = \
    '<table><tr><td> <img src="{}" alt="img"></td></tr><tr><td> <img src="{}" alt="img"></td></tr></table>' \
    .format(
        picture_name_with_corona + "-lineplot.png",
        picture_name_with_corona + "-corr.png")
    """
df_pearson_spearman_before_corona["pearson_spearman"] = \
    df_pearson_spearman_before_corona["pearson"].map('${:,.2f}'.format).astype(str) + ", " + df_pearson_spearman_before_corona["spearman"].map('${:,.2f}'.format).astype(str)
df_pearson_spearman_with_corona["pearson_spearman"] = \
    df_pearson_spearman_with_corona["pearson"].map('${:,.2f}'.format).astype(str) + ", " + df_pearson_spearman_with_corona["spearman"].map('${:,.2f}'.format).astype(str)
df = pd.DataFrame({#"restaurant_name":[restaurant.value for restaurant in Restaurant],
              "pear_s_before":df_pearson_spearman_before_corona["pearson_spearman"].to_list(),
              "before_corona_img":df_pearson_spearman_before_corona["before_corona"].to_list(),
              "pear_s_with":df_pearson_spearman_with_corona["pearson_spearman"].to_list(),
              "with_corona_img":df_pearson_spearman_with_corona["with_corona"].to_list()})

display(HTML(df.to_html(escape=False, index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>pear_s_before</th>
#       <th>before_corona_img</th>
#       <th>pear_s_with</th>
#       <th>with_corona_img</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>$0.93, $0.50</td>
#       <td><img src="fwg-butcher-uster-before-corona-corr.png" alt="img"></td>
#       <td>$0.50, $0.36</td>
#       <td><img src="fwg-butcher-uster-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.12, $0.07</td>
#       <td><img src="fwg-negishi-metalli-before-corona-corr.png" alt="img"></td>
#       <td>$0.05, $0.00</td>
#       <td><img src="fwg-negishi-metalli-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.16, $0.27</td>
#       <td><img src="fwg-butcher-aarbergergasse-before-corona-corr.png" alt="img"></td>
#       <td>$0.13, $0.16</td>
#       <td><img src="fwg-butcher-aarbergergasse-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.30, $0.25</td>
#       <td><img src="fwg-nooch-aarbergergasse-before-corona-corr.png" alt="img"></td>
#       <td>$0.26, $0.23</td>
#       <td><img src="fwg-nooch-aarbergergasse-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.00, $0.15</td>
#       <td><img src="fwg-nooch-barfi-before-corona-corr.png" alt="img"></td>
#       <td>$-0.11, $0.02</td>
#       <td><img src="fwg-nooch-barfi-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.03, $0.18</td>
#       <td><img src="fwg-missmiu-europaallee-before-corona-corr.png" alt="img"></td>
#       <td>$0.21, $0.23</td>
#       <td><img src="fwg-missmiu-europaallee-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.08, $-0.01</td>
#       <td><img src="fwg-nooch-mallofSwitzerland-before-corona-corr.png" alt="img"></td>
#       <td>$0.06, $0.03</td>
#       <td><img src="fwg-nooch-mallofSwitzerland-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.60, $0.65</td>
#       <td><img src="fwg-nooch-mattenhof-before-corona-corr.png" alt="img"></td>
#       <td>$0.00, $-0.06</td>
#       <td><img src="fwg-nooch-mattenhof-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.23, $0.09</td>
#       <td><img src="fwg-butcher-metalli-before-corona-corr.png" alt="img"></td>
#       <td>$0.11, $0.03</td>
#       <td><img src="fwg-butcher-metalli-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.19, $0.05</td>
#       <td><img src="fwg-negishi-pilatusstrasse-before-corona-corr.png" alt="img"></td>
#       <td>$-0.12, $-0.17</td>
#       <td><img src="fwg-negishi-pilatusstrasse-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.08, $-0.14</td>
#       <td><img src="fwg-nooch-richti-before-corona-corr.png" alt="img"></td>
#       <td>$0.04, $-0.05</td>
#       <td><img src="fwg-nooch-richti-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.27, $-0.27</td>
#       <td><img src="fwg-outback-stad-before-corona-corr.png" alt="img"></td>
#       <td>$-0.29, $-0.32</td>
#       <td><img src="fwg-outback-stad-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.16, $-0.06</td>
#       <td><img src="fwg-negishi-steinen-before-corona-corr.png" alt="img"></td>
#       <td>$-0.07, $-0.04</td>
#       <td><img src="fwg-negishi-steinen-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$0.80, $0.87</td>
#       <td><img src="fwg-nooch-uster-before-corona-corr.png" alt="img"></td>
#       <td>$0.34, $0.01</td>
#       <td><img src="fwg-nooch-uster-after-corona-corr.png" alt="img"></td>
#     </tr>
#     <tr>
#       <td>$-0.04, $-0.04</td>
#       <td><img src="fwg-butcher-zuerichWest-before-corona-corr.png" alt="img"></td>
#       <td>$-0.20, $-0.19</td>
#       <td><img src="fwg-butcher-zuerichWest-after-corona-corr.png" alt="img"></td>
#     </tr>
#   </tbody>
# </table>
